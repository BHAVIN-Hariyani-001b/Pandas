# %% [markdown]
# - 1 - understand the data set
# - 2 - identify the problems
# - 3 - plan next steps

# %%
import pandas as pd

# %%
df = pd.read_csv('./datafile/sales_data_sample.csv',encoding='latin1')

# heda() and tail() help to row and column print 
# hade() and tail() is by defulat five five row's return 
# print(df.head(10)) # head is use to staring n row display 
df.head(10) # direact print in jupyter notebook
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
# print(df.tail(5)) # tail is provide to last n number of row return 
df.tail(5)  # direact print in jupyter notebook
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %% [markdown]
# - 1.how many column , row in data
# - 2.which type's of column in data and which type's of data store in row,column
# - 3.missing data find

# %%
# number of row and column 
# column name
# not null count
# data type (int64,float64)
# memory usage of the data fream 
# object  data type mining is string,category and etc..
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
data = {
    "Name":["Ram","Shyam","Ghanshyam"],
    "Age":[10,20,30],
    "City":['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
# stap - 1 semple datafream

data = {
    "Name":["Ram","Shyam","Ghanshyam","Krishna","Arjun","Karna","Sita","Radh"],
    "Age":[10,20,30,40,50,60,70,80],
    "Salary":[50000,60000,70000,80000,90000,100000,110000,120000],
    "City":["Nagpur","Mumbai","Delhi","Pune","Bangalore","Kolkata","Chennai","Ahmedabad"],
    "Performance Score":[90,34,65,76,87,34,76,100]
}

df = pd.DataFrame(data)
df
# df.info()
df.describe() # describe method is use to overoll statistics provide like (min,mean,max,...)
# Out:
#              Age         Salary  Performance Score
# count   8.000000       8.000000           8.000000
# mean   45.000000   85000.000000          70.250000
# std    24.494897   24494.897428          24.719859
# min    10.000000   50000.000000          34.000000
# 25%    27.500000   67500.000000          57.250000
# 50%    45.000000   85000.000000          76.000000
# 75%    62.500000  102500.000000          87.750000
# max    80.000000  120000.000000         100.000000

# %%
# show data
df
# Out:
#         Name  Age  Salary       City  Performance Score
# 0        Ram   10   50000     Nagpur                 90
# 1      Shyam   20   60000     Mumbai                 34
# 2  Ghanshyam   30   70000      Delhi                 65
# 3    Krishna   40   80000       Pune                 76
# 4      Arjun   50   90000  Bangalore                 87
# 5      Karna   60  100000    Kolkata                 34
# 6       Sita   70  110000    Chennai                 76
# 7       Radh   80  120000  Ahmedabad                100

# %%
# find shape of dataframe and return tuple frist row and column
df.shape
# Out:
# (8, 5)

# %%
# find column name of dataframe
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'City', 'Performance Score'], dtype='object')

# %% [markdown]
# - how to select specific column
# - filter row's
# - combine multiple condition's

# %%
# select column 
print(df['Name']) 
df[df['Age'] > 52] # apply bool condition
# Out:
# 0          Ram
# 1        Shyam
# 2    Ghanshyam
# 3      Krishna
# 4        Arjun
# 5        Karna
# 6         Sita
# 7         Radh
# Name: Name, dtype: object
#     Name  Age  Salary       City  Performance Score
# 5  Karna   60  100000    Kolkata                 34
# 6   Sita   70  110000    Chennai                 76
# 7   Radh   80  120000  Ahmedabad                100

# %%
# select mutiple column 
df[['Name','City']]
# Out:
#         Name       City
# 0        Ram     Nagpur
# 1      Shyam     Mumbai
# 2  Ghanshyam      Delhi
# 3    Krishna       Pune
# 4      Arjun  Bangalore
# 5      Karna    Kolkata
# 6       Sita    Chennai
# 7       Radh  Ahmedabad

# %%
# filter rows
high_salary = df[df['Salary'] > 80000]
high_salary
# Out:
#     Name  Age  Salary       City  Performance Score
# 4  Arjun   50   90000  Bangalore                 87
# 5  Karna   60  100000    Kolkata                 34
# 6   Sita   70  110000    Chennai                 76
# 7   Radh   80  120000  Ahmedabad                100

# %%
# mutiple condition use and filter data
# using AND (&) 
df[(df['Salary'] > 80000) & (df['Age'] > 40)]
# Out:
#     Name  Age  Salary       City  Performance Score
# 4  Arjun   50   90000  Bangalore                 87
# 5  Karna   60  100000    Kolkata                 34
# 6   Sita   70  110000    Chennai                 76
# 7   Radh   80  120000  Ahmedabad                100

# %%
# using OR (|) 
df[(df['Age'] > 50) | (df['Performance Score'] > 90)]
# Out:
#     Name  Age  Salary       City  Performance Score
# 5  Karna   60  100000    Kolkata                 34
# 6   Sita   70  110000    Chennai                 76
# 7   Radh   80  120000  Ahmedabad                100
